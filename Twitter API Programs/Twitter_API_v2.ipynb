# %% [markdown]
# ## Twiter Object Documentation
#
# #### Twitter Source Documentation for info on tweet objects:
#
# https://developer.twitter.com/en/docs/twitter-api/data-dictionary/object-model/tweet
#
# https://developer.twitter.com/en/docs/twitter-api/tweets/lookup/api-reference/get-tweets
#
#
# #### Tweet object structure:
# -- Tweet object has long list of root level fields such as id, text, created_at
#
# -- Tweet object is parent to several child objects including user, media, poll, and place
#
# -- Use field paramater "tweet.fields" when requesting root level fields on tweet object
#
# - tweet.fields:attachments, author_id, context_annotations, conversation_id, created_at,
# entities, geo, id, in_reply_to_user_id, lang,non_public_metrics, public_metrics, organic_metrics,
# promoted_metrics, possibly_sensitive, referenced_tweets, source, text, withheld
#
#
# -- Child object paramaters (query paramaters):
#
# - media.fields:  duration_ms, height, media_key, preview_image_url, type, url, width, public_metrics,
# non_public_metrics, organic_metrics, promoted_metrics
#
# - place.fields:  contained_within, country, country_code, full_name, geo, id, name, place_type
#
# - poll.fields:  duration_minutes, end_datetime, id, options, voting_status
#
# - user.fields:  created_at, description, entities, id, location, name,
# pinned_tweet_id, profile_image_url, protected, public_metrics, url, username, verified, withheld
#
# --Other query paramaters:
#
# - expansions:  attachments.poll_ids, attachments.media_keys, author_id, entities.mentions.username,
# geo.place_id, in_reply_to_user_id, referenced_tweets.id, referenced_tweets.id.author_id

# %%
## Import dependencies

# Utilities
import requests
import json
import pandas as pd
import time

# Keys
from config import bearer_token

# %%
##  Set authorization for Twitter     

headers = {"Authorization": "Bearer {}".format(bearer_token)}

# %%
## Set URL and query paramaters; create response object

# Set query keywords
query = "covid -is:retweet lang:en"

#Set place fields to return place location if available 
place_fields = "place.fields=contained_within,country,country_code,geo"

# Set tweet fields to return
tweet_fields = "tweet.fields=author_id,lang,public_metrics,created_at"

# Set max results per page
max_results = 'max_results=100'

# Set initial value of next token 
next = ''

# Set URL
url = "https://api.twitter.com/2/tweets/search/recent?query={}&{}&{}&{}".format(query, place_fields, tweet_fields,
                                                                                max_results, next)

# Create response object
response = requests.request("GET", url, headers=headers)

# %%
len(response.json()['data'])
# Out:
# 99

# %%
## Create while loop to paginate through JSON responses so long as next_token in return in metadata at end of file

# NOTE:  Replace counter fucntion with "While True" format

counter = 1

# Create list to store responses
json_output =[]

# Change while loop back to 'while True:' once output formatting is determined

while True:
    
    # Submit twitter request
    response = requests.request("GET", url, headers=headers)
    
    # Check and print status / first text message of json response to confirm unique pulls
    print(response.status_code)
    print(response.json()['data'][0]['text'])
    if response.status_code != 200:
        raise Exception(response.status_code, response.text)
    
    # Save JSON response to json_output file
    json_output.append(response.json())
    
    # Check to see if 'next_token' in JSON response metatdata; if so, reset 'next' to iterate; if not, break
    if 'next_token' not in response.json()['meta']:
        break
    next = f"next_token={response.json()['meta']['next_token']}"
    print(next)
    print(f"Request: {counter}")
    print(f"Tweets pulled: {counter*100}")
    print('-------------------------------------------------')
    
    # Pause iteration for 20 seconds to allow unique next_token to generate and json to load
    time.sleep(20)
    
    # Iterate counter
    counter += 1

    
print("")
print("-----------------")
print("API Query Results")
print("-----------------")
print(f"Pages:            {len(json_output)}")
print(f"Tweets per Page:  {len(json_output[0]['data'])}")
# Out:
# 200
# @realDonaldTrump You’re off your rocker, Donnie.  Either you’re the ultimate sore loser or you’ve dipped into your Covid-infected son’s cokebag.
# next_token=b26v89c19zqg8o3fosbvxqzrf4rjxtqi8g5vzu367imbh
# Tweets pulled: 100
# -------------------------------------------------
# 200
# As COVID test sites reach capacity, Washington state leaders urge restraint and judgment https://t.co/yOusQK0JuK
# next_token=b26v89c19zqg8o3fosbvxqzrf4rtml8jp16r8nk94b4al
# Tweets pulled: 200
# -------------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-74-43f1b9089019> in <module>
#      33
#      34     # Pause iteration for 20 seconds to allow unique next_token to generate and json to load
# ---> 35     time.sleep(20)
#      36
#      37     # Iterate counter
#
# KeyboardInterrupt:

# %%
json_output[0]
# Out:
# {'data': [{'lang': 'en',
#    'text': 'I’m kinda possessive too.. I feel like covid wiped your girl clean like a white board like I forgot all kinds of important ish. School, work, passwords.... wait no I always forget passwords.. but work and school... 🤥',
#    'created_at': '2020-11-20T04:12:26.000Z',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'author_id': '236094999',
#    'id': '1329638710770589697'},
#   {'lang': 'en',
#    'text': "@heyrabeckkkkk I am now.  I'm tired too.  I got a headwind before the election &amp; now I have to take a breather.  My closest coworker today bet me (again) that elections can't be corrupted, overturned, &amp; I'm a conspiracy theorist on COVID. I'll wait....ugh",
#    'created_at': '2020-11-20T04:12:26.000Z',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'author_id': '352458151',
#    'id': '1329638710305042432'},
#   {'lang': 'en',
#    'text': '@Reuters Ahem! *clears throat* MY KIDS SCHOOL HAS BEEN CLOSED TWICE FOR COVID!!! ONCE FOR A STUDENT &amp; THE OTHER FOR A TEACHER!!! #EXCUSEME',
#    'created_at': '2020-11-20T04:12:26.000Z',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'author_id': '4908194346',
#    'id': '1329638709948416001'},
#   {'lang': 'en',
#    'text': "@MaddowBlog I feel so bad for you and Susan. I'm exhausted from People (some family) not taking this seriously. And Hugo Chavez is dead not from Covid (2013) And that's what America is Fighting during a PANDEMIC??!! Shameful.",
#    'created_at': '2020-11-20T04:12:26.000Z',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'author_id': '605844446',
#    'id': '1329638709826777090'},
#   {'lang': 'en',
#    'text': '@EAwrite @kaitlancollins Today it was reported that she was interested in a job with the Biden WH Covid team..she is shameless',
#    'created_at': '2020-11-20T04:12:26.000Z',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'author_id': '955183813629501445',
#    'id': '1329638709541679104'},
#   {'lang': 'en',
#    'text': '"Idiotic Covid edicts" is putting it mildly. https://t.co/w9rLpQZgxo',
#    'created_at': '2020-11-20T04:12:26.000Z',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'author_id': '1248114281075200000',
#    'id': '1329638707943489538'},
#   {'lang': 'en',
#    'text': "If Donald Trump was still the President he'd blame it on Mexico \n#TransitionNow\nhttps://t.co/EbcUy6Tpn9 via @nbcnews",
#    'created_at': '2020-11-20T04:12:25.000Z',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'author_id': '831532917323083779',
#    'id': '1329638707360575491'},
#   {'lang': 'en',
#    'text': '@CDCgov If you look at the large numbers of the American populace. you will find that less than 0.0001% of the American population has gotten Covid-19. Quit controlling the American people and give us our freedom back. You are destroying our economy.',
#    'created_at': '2020-11-20T04:12:25.000Z',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'author_id': '707667389710618624',
#    'id': '1329638705041080321'},
#   {'lang': 'en',
#    'text': '@TeamLouie Hi Louie . Sorry things went this way for you . I’d be very disappointed myself . Prayers for you , I hope you get thru this Covid and have a full recovery bud 👊🏻.',
#    'created_at': '2020-11-20T04:12:25.000Z',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'author_id': '1312484633188196358',
#    'id': '1329638704802115585'},
#   {'lang': 'en',
#    'text': 'Covid looking at the Gucci vs Jeezy compound after party #VERZUZ https://t.co/7DIzT7ulVe',
#    'created_at': '2020-11-20T04:12:25.000Z',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'author_id': '848448889736658944',
#    'id': '1329638703703019521'}],
#  'meta': {'newest_id': '1329638710770589697',
#   'oldest_id': '1329638703703019521',
#   'result_count': 10,
#   'next_token': 'b26v89c19zqg8o3fosbvxklaivcas9inmxuo1zkfaoakd'}}

# %%
response.json()['data'][0]['text']
# Out:
# '@philothea13 @TPCarney How’s that working out for you?\nhttps://t.co/HI8asSyONV'

# %%
# Review first item in json_output
json_output[0]['data'][0]['text']
# Out:
# 'I’m kinda possessive too.. I feel like covid wiped your girl clean like a white board like I forgot all kinds of important ish. School, work, passwords.... wait no I always forget passwords.. but work and school... 🤥'

# %%
# Store raw data file 
unformatted_df = pd.DataFrame(json_output)
unformatted_df.to_csv('../Twitter_Data/unformatted_data.csv', index=False)
unformatted_df
# Out:
#                                                    data  \
# 0     [{'lang': 'en', 'text': 'I’m kinda possessive ...
# 1     [{'lang': 'en', 'id': '1329638795470278657', '...
# 2     [{'author_id': '283604227', 'public_metrics': ...
# 3     [{'text': '@CP24 If we have the most strict lo...
# 4     [{'lang': 'en', 'text': 'Dr. Fauci says vaccin...
# ...                                                 ...
# 1001  [{'lang': 'en', 'text': 'Covid gadget alert: T...
# 1002  [{'author_id': '779890695695896576', 'public_m...
# 1003  [{'lang': 'en', 'text': '@FDRLST It's all abou...
# 1004  [{'public_metrics': {'retweet_count': 0, 'repl...
# 1005  [{'author_id': '16407420', 'public_metrics': {...
#
#                                                    meta
# 0     {'newest_id': '1329638710770589697', 'oldest_i...
# 1     {'newest_id': '1329638795470278657', 'oldest_i...
# 2     {'newest_id': '1329638878001684481', 'oldest_i...
# 3     {'newest_id': '1329638962546307073', 'oldest_i...
# 4     {'newest_id': '1329639050660114432', 'oldest_i...
# ...                                                 ...
# 1001  {'newest_id': '1329852356369010691', 'oldest_i...
# 1002  {'newest_id': '1329852440401866756', 'oldest_i...
# 1003  {'newest_id': '1329852528276754436', 'oldest_i...
# 1004  {'newest_id': '1329852608924815360', 'oldest_i...
# 1005  {'newest_id': '1329852696065662979', 'oldest_i...
#
# [1006 rows x 2 columns]

# %%
# Loop through json_output to grab tweet data; top line only iterates through data block

# Dictionary to store output
tweet_data = {}
tweet_data['ID'] = []
tweet_data['Date'] = []
tweet_data['Retweets'] = []
tweet_data['Replies'] = []
tweet_data['Likes'] = []
tweet_data['Quotes'] = []
tweet_data['Tweet'] = []


for w in range(0, len(json_output)):
    
    for x in range(0, len(json_output[w]['data'])):
        
        # Selet and print data
        id = json_output[w]['data'][x]['id']
        text = json_output[w]['data'][x]['text']
        date = json_output[w]['data'][x]['created_at']

        # Append selected data to dictionary, print output
        tweet_data['ID'].append(id)
        tweet_data['Date'].append(date)
        tweet_data['Tweet'].append(text)
        
#        print(text)
#        print(date)       
        
        for y in range(0, len(json_output[w]['data'][x])):
            
            # Selet data
            retweet_count = json_output[w]['data'][x]['public_metrics']['retweet_count']
            reply_count = json_output[w]['data'][x]['public_metrics']['reply_count']
            like_count = json_output[w]['data'][x]['public_metrics']['like_count']
            quote_count = json_output[w]['data'][x]['public_metrics']['quote_count']
        
        # Append selected data to dictionary, print output
        tweet_data['Retweets'].append(retweet_count)
        tweet_data['Replies'].append(reply_count)
        tweet_data['Likes'].append(like_count)
        tweet_data['Quotes'].append(quote_count)
        
#        print(retweet_count, reply_count, like_count, quote_count)
#        print('-------------------------------------------------')

# %%
# Review organized data
df = pd.DataFrame(tweet_data)
df.tail()
# Out:
#                         ID                      Date  Retweets  Replies  \
# 10047  1329852691141443584  2020-11-20T18:22:43.000Z         0        0
# 10048  1329852691032510466  2020-11-20T18:22:43.000Z         0        0
# 10049  1329852690923479042  2020-11-20T18:22:43.000Z         0        0
# 10050  1329852689539362817  2020-11-20T18:22:43.000Z         0        0
# 10051  1329852689493049344  2020-11-20T18:22:43.000Z         0        0
#
#        Likes  Quotes                                              Tweet
# 10047      0       0  According to the latest COVID-19 data, 250,000...
# 10048      0       0  I work answering an RN COVID hotline and can v...
# 10049      0       0  The Broncos announced that Sunday will be thei...
# 10050      0       0  @Stats_Burger @numbers_truth "die from COVID-1...
# 10051      0       0  Lmao well why would you? Stupid Americans have...

# %%
# Filter by mask
mask_df = df[df['Tweet'].str.contains('mask|face covering')]
mask_df
# Out:
#                         ID                      Date  Retweets  Replies  \
# 36     1329638955268993025  2020-11-20T04:13:25.000Z         0        0
# 55     1329639128007249921  2020-11-20T04:14:06.000Z         0        0
# 67     1329639209666301952  2020-11-20T04:14:25.000Z         0        0
# 80     1329639385864704000  2020-11-20T04:15:07.000Z         0        0
# 84     1329639383260082176  2020-11-20T04:15:07.000Z         0        0
# ...                    ...                       ...       ...      ...
# 9982   1329852187934154753  2020-11-20T18:20:43.000Z         0        0
# 10002  1329852356369010691  2020-11-20T18:21:23.000Z         0        0
# 10005  1329852354334765061  2020-11-20T18:21:23.000Z         0        0
# 10027  1329852525831327746  2020-11-20T18:22:04.000Z         0        0
# 10039  1329852605783289856  2020-11-20T18:22:23.000Z         0        0
#
#        Likes  Quotes                                              Tweet
# 36         0       0  @DarciSings @Zigmanfreud @GavinNewsom He’s a c...
# 55         0       0  Top WHO official in Europe says face masks cou...
# 67         0       0  For the love of God, everyone: Wear your masks...
# 80         0       0  @JoeBiden If masks stop the spread of COVID it...
# 84         0       0  #FridayThoughts BEEN MASKING FOR MONTHS, Yet s...
# ...      ...     ...                                                ...
# 9982       0       0  How many Republican politicians vs Democrat po...
# 10002      0       0  Covid gadget alert: Think your trusty mask nee...
# 10005      0       0  @UHOHitsMark @drmkry @aVoice4MA6 @Don_Fabbri T...
# 10027      0       0  @GatoPolitico5 @tvanhorbeck @cnnbrk I AM SO BE...
# 10039      0       0  Two things:\n\n1) U.S. Policy re: Covid-19 spo...
#
# [462 rows x 7 columns]

# %%
# Filter by vaccine
vaccine_df = df[df['Tweet'].str.contains('vaccine')]
vaccine_df
# Out:
#                        ID                      Date  Retweets  Replies  Likes  \
# 14    1329638788507856897  2020-11-20T04:12:45.000Z         0        0      0
# 22    1329638876877516800  2020-11-20T04:13:06.000Z         0        0      0
# 41    1329639050387496960  2020-11-20T04:13:47.000Z         0        0      0
# 49    1329639039348170752  2020-11-20T04:13:45.000Z         0        0      0
# 69    1329639205337788416  2020-11-20T04:14:24.000Z         0        0      0
# ...                   ...                       ...       ...      ...    ...
# 9871  1329851166335721473  2020-11-20T18:16:40.000Z         0        0      0
# 9902  1329851508821733378  2020-11-20T18:18:01.000Z         0        0      0
# 9962  1329852017112543232  2020-11-20T18:20:02.000Z         0        0      0
# 9989  1329852182623969281  2020-11-20T18:20:42.000Z         0        0      0
# 9996  1329852271971143685  2020-11-20T18:21:03.000Z         0        0      0
#
#       Quotes                                              Tweet
# 14         0  Coronavirus | Oxford University COVID-19 vacci...
# 22         0  Serum Institute of India’s CEO Adar Poonawalla...
# 41         0  @berrybram @channel5_tv Some things come back ...
# 49         0  @NicolaSturgeon\n@ScotGovFM\n@theSNP\nWATCH fi...
# 69         0  Covid vaccine to send flight costs skyrocketin...
# ...      ...                                                ...
# 9871       0  @IndianExpress Check out this blog to know wha...
# 9902       0  Geraldo Rivera suggests naming COVID-19 vaccin...
# 9962       0  Covid vaccine How Indian airlines, airports ar...
# 9989       0  @PSformaldehyde @EdwardNorton @neal_katyal @Pr...
# 9996       0  Vaccines prevent infections, so how does a Cov...
#
# [612 rows x 7 columns]

# %%
# Filter by lockdown
lockdown_df = df[df['Tweet'].str.contains('lockdown|quarantine|stay at home')]
lockdown_df
# Out:
#                         ID                      Date  Retweets  Replies  \
# 16     1329638784229646336  2020-11-20T04:12:44.000Z         0        0
# 30     1329638962546307073  2020-11-20T04:13:26.000Z         0        0
# 2085       0  @DM_NorthWest  Please come in Golden Park, 110...
# 2174       0  My lungs are weak if I get COVID-19 death is g...
# 2245       0  It is important to act responsibility and adhe...
# 3015       0  hi, just wanted to remind you guys that we are...
# 3055       0  @SenRickScott there is no science beyond polit...
# 3277       0  @SteveKornacki you need to brief the American ...
# 3318       0  If it’s revealed years from now wearing a mask...
# 3369       0  "I hear ventilation in Santa’s workshop is not...
# 3404       0  @mcelhearn @timspector @MattHancock I think, b...
# 3535       0  #Covid face masks and social distancing is onl...
# 3596       0  Flu cases are down because people are using ma...
# 3709       0  It's so sad that liberals gathered by the thou...
# 3985       0  Confirming his positive COVID test, Rick Scott...
# 4134       0  @nationalexpress don’t see much social distanc...
# 4168       0  Do you really want to know how to avoid COVID-...
# 4360       0  Didn’t Republicans call Sherrod Brown an assho...
# 4951       0  imagine following all the rules, wearing a mas...
# 5200       0  @brad_dickson I tend to agree. I see doctors a...
# 5297       0  @JennWongSilver @ashishkjha No, Dr. Sha had it...
# 6281       0  As RTE colleagues were caught hypocritically b...
# 6586       0  @shelly2161 @kylegriffin1 you're a fucking mor...
# 6711       0  @mchooyah We might end up seeing fewer flu dea...
# 6725       0  The flu vaccine is available at clinics and ph...
# 6727       0  @yetanotherecon @Minute_Militia @CultureWarlor...
# 6738       0  @DonaldJTrumpJr @realDonaldTrump  has let Covi...
# 6847       0  @AmazonUK @AmazonHelp @GOVUK #hse\n\nAmazon yo...
# 6967       0  Throughout the COVID-19 pandemic, our brokers ...
# 7002       0  For those battling addiction, COVID-19 has mad...
# 7022       0  Yep no proposals while covid exist none of us ...
# 7432       0  Keep this to the forefront of the news.  When ...
# 7505       0  Zoom fatigue is real, so is covid fatigue &amp...
# 7608       0  @disclosetv And that's why big corporations lo...
# 7710       0  @thehill Dear Ppl, if ur governors either lack...
# 7730       0  Remember folks, we are not helpless during thi...
# 7800       0  Thus far NO shutdowns, no mandates, no amount ...
# 7830       0  @mchooyah @catturd2 Flu season generally peaks...
# 7839       0  A friend said flu is down because of masking, ...
# 8124       0  This has led to a corresponding increase in de...
# 8188       0  "I think it will start with a concerted effort...
# 8382       0  Getting my covid test today cos all my co-work...
# 8491       0  Y’all can do what you want for thanksgiving. O...
# 8567       0  @mrahmedmathsuk @RogersHistory Looking at the ...
# 8577       0  @FloridaRoundup @MelissainJax a COVID vaccine ...
# 8713       0  Every nurse I’ve spoken to says that it’s the ...
# 9040       0  @RadioMunkeh Hi Jason. Usually, one team membe...
# 9126       0  @RadDad0306 @dcb_ovo @Eagles Yeah so then why ...
# 9411       0  My 23 year old nephew lives in Seattle, he is ...
# 9894       0  As the Government updates advice on preventing...
# 9982       0  How many Republican politicians vs Democrat po...

# %%
# Push dataframes to CSV

df.to_csv('../Twitter_Data/tweet_data1.csv', index=False)
mask_df.to_csv('../Twitter_Data/mask_data1.csv', index=False)
vaccine_df.to_csv('../Twitter_Data/vaccine_data1.csv', index=False)
lockdown_df.to_csv('../Twitter_Data/lockdown_data1.csv', index=False)
distance_df.to_csv('../Twitter_Data/distance_data1.csv', index=False)
